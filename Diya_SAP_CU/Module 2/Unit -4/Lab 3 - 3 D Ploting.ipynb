# %% [markdown]
# # Lab 3 - 3 D Ploting

# %% [markdown]
# # Program 1 - Three-Dimensional Plotting in Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()    #USE TO CREATE A NEW FIG
ax = plt.axes(projection ='3d')

# %% [markdown]
# # Plotting 3-D Lines and Points

# %%
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining all 3 axes
z = np.linspace(0, 1, 1000)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot')
plt.show()

# %% [markdown]
# # Program 2 - Logarithmic Axes in Matplotlib

# %% [markdown]
# # Without Logarithmic Scale.

# %%
# Logarithmic Axes in Matplotlib
import matplotlib.pyplot as plt

# exponential function y = 10^x
data = [10**i for i in range(5)]

plt.plot(data)

# %% [markdown]
# # Y-axis Logarithmic Scale.

# %%
import matplotlib.pyplot as plt

# exponential function y = 10^x
data = [10**i for i in range(5)]

# convert y-axis to Logarithmic scale
plt.yscale("log")

plt.plot(data)

# %% [markdown]
# # X-axis Logarithmic Scale.

# %%
import matplotlib.pyplot as plt

# exponential function x = 10^y
datax = [ 10**i for i in range(5)]
datay = [ i for i in range(5)]

#convert x-axis to Logarithmic scale
plt.xscale("log")

plt.plot(datax,datay)
